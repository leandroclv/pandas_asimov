# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %% [markdown]
# ###Series

# %%
labels = ['a', 'b', 'c']
minha_lista = [10, 20, 30]
arr = np.array([10, 20, 30])
d = {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data = labels, index = minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(labels, minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1 = pd.Series([1,2,3,4], index = ['EUA', 'Alemanha', 'Russia', 'Japão'])
ser1
# Out:
# EUA         1
# Alemanha    2
# Russia      3
# Japão       4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4], index = ['EUA', 'Alemanha', 'Italia', 'Japão'])
ser2
# Out:
# EUA         1
# Alemanha    2
# Italia      5
# Japão       4
# dtype: int64

# %%
ser1['EUA']
# Out:
# np.int64(1)

# %%
ser1['Alemanha']
# Out:
# np.int64(2)

# %%
ser1[['Alemanha', 'Russia']]
# Out:
# Alemanha    2
# Russia      3
# dtype: int64

# %%
ser1 + ser2
# Out:
# Alemanha    4.0
# EUA         2.0
# Italia      NaN
# Japão       8.0
# Russia      NaN
# dtype: float64

# %% [markdown]
# ###DataFrame

# %%
df = pd.DataFrame(randn(5,4), index = ['A', 'B', 'C', 'D', 'E'], columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A  0.871098 -0.665590 -1.926392 -1.618328
# B  0.531324 -0.202678 -0.764131  0.322598
# C  0.766405  1.167030  0.392177  2.574728
# D  0.091734 -0.205567  0.633671  2.270462
# E  0.016833 -0.184039 -0.512652 -0.452594

# %%
df['W']
# Out:
# A    0.871098
# B    0.531324
# C    0.766405
# D    0.091734
# E    0.016833
# Name: W, dtype: float64

# %%
df[['W', 'X']]
# Out:
#           W         X
# A  0.871098 -0.665590
# B  0.531324 -0.202678
# C  0.766405  1.167030
# D  0.091734 -0.205567
# E  0.016833 -0.184039

# %%
df[['W']]
# Out:
#           W
# A  0.871098
# B  0.531324
# C  0.766405
# D  0.091734
# E  0.016833

# %%
df['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A  0.871098 -0.665590 -1.926392 -1.618328 -1.055294
# B  0.531324 -0.202678 -0.764131  0.322598 -0.232807
# C  0.766405  1.167030  0.392177  2.574728  1.158583
# D  0.091734 -0.205567  0.633671  2.270462  0.725405
# E  0.016833 -0.184039 -0.512652 -0.452594 -0.495819

# %%
del df['new'] #ou df.drop('new', axis = 1) 1-> colunas e 0-> linhas
df
# Out:
#           W         X         Y         Z
# A  0.871098 -0.665590 -1.926392 -1.618328
# B  0.531324 -0.202678 -0.764131  0.322598
# C  0.766405  1.167030  0.392177  2.574728
# D  0.091734 -0.205567  0.633671  2.270462
# E  0.016833 -0.184039 -0.512652 -0.452594

# %%
df
# Out:
#           W         X         Y         Z
# A  0.871098 -0.665590 -1.926392 -1.618328
# B  0.531324 -0.202678 -0.764131  0.322598
# C  0.766405  1.167030  0.392177  2.574728
# D  0.091734 -0.205567  0.633671  2.270462
# E  0.016833 -0.184039 -0.512652 -0.452594

# %%
df.loc['A']
# Out:
# W    0.871098
# X   -0.665590
# Y   -1.926392
# Z   -1.618328
# Name: A, dtype: float64

# %%
df.loc[['A', 'B']]
# Out:
#           W         X         Y         Z
# A  0.871098 -0.665590 -1.926392 -1.618328
# B  0.531324 -0.202678 -0.764131  0.322598

# %%
df.iloc[0,2]
# Out:
# np.float64(-1.926392129371847)
