# %%
import pandas as pd
import numpy as np

# %%
df_viagem = pd.read_csv('2026_Viagem.csv', encoding='latin', sep=';')
pd.set_option('display.max_columns', None)
df_viagem.head(3)
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)   Situação  \
# 0                             21116870                 000073/26  Realizada
# 1                             21342207                 000001/26  Realizada
# 2                             21343024                 000001/26  Realizada
#
#   Viagem Urgente Justificativa Urgência Viagem  Código do órgão superior  \
# 0            SIM         Atraso na solicitação                     26000
# 1            NÃO                Sem informação                     52000
# 2            NÃO                Sem informação                     26000
#
#    Nome do órgão superior  Código órgão solicitante  \
# 0  Ministério da Educação                     26436
# 1    Ministério da Defesa                     52121
# 2  Ministério da Educação                     26247
#
#                               Nome órgão solicitante    CPF viajante  \
# 0  Instituto Federal de Educação, Ciência e Tecno...  ***.240.140-**
# ...

# %%
df_viagem['Nome do órgão superior'] #Selecionou uma coluna
# Out:
# 0                                   Ministério da Educação
# 1                                     Ministério da Defesa
# 2                                   Ministério da Educação
# 3                                     Ministério da Defesa
# 4                                     Ministério da Defesa
#                                ...
# 88902    Banco Central do Brasil - Orçamento Fiscal e S...
# 88903    Banco Central do Brasil - Orçamento Fiscal e S...
# 88904    Banco Central do Brasil - Orçamento Fiscal e S...
# 88905    Banco Central do Brasil - Orçamento Fiscal e S...
# 88906    Banco Central do Brasil - Orçamento Fiscal e S...
# Name: Nome do órgão superior, Length: 88907, dtype: object

# %%
df_viagem['Valor diárias'] #Selecionou uma coluna
# Out:
# 0         107,83
# 1           0,00
# 2           0,00
# 3           0,00
# 4           0,00
#           ...
# 88902     904,09
# 88903    2758,64
# 88904    2758,64
# 88905    1204,09
# 88906    1109,09
# Name: Valor diárias, Length: 88907, dtype: object

# %%
colunas = ['Nome do órgão superior', 'Valor diárias'] #Selecionou mais de uma coluna
df_viagem[colunas]
# Out:
#                                   Nome do órgão superior Valor diárias
# 0                                 Ministério da Educação        107,83
# 1                                   Ministério da Defesa          0,00
# 2                                 Ministério da Educação          0,00
# 3                                   Ministério da Defesa          0,00
# 4                                   Ministério da Defesa          0,00
# ...                                                  ...           ...
# 88902  Banco Central do Brasil - Orçamento Fiscal e S...        904,09
# 88903  Banco Central do Brasil - Orçamento Fiscal e S...       2758,64
# 88904  Banco Central do Brasil - Orçamento Fiscal e S...       2758,64
# 88905  Banco Central do Brasil - Orçamento Fiscal e S...       1204,09
# 88906  Banco Central do Brasil - Orçamento Fiscal e S...       1109,09
#
# [88907 rows x 2 columns]

# %%
df_viagem['Nome do órgão superior'].str.upper()
# Out:
# 0                                   MINISTÉRIO DA EDUCAÇÃO
# 1                                     MINISTÉRIO DA DEFESA
# 2                                   MINISTÉRIO DA EDUCAÇÃO
# 3                                     MINISTÉRIO DA DEFESA
# 4                                     MINISTÉRIO DA DEFESA
#                                ...
# 88902    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88903    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88904    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88905    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88906    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# Name: Nome do órgão superior, Length: 88907, dtype: object

# %%
df_viagem['Nome do órgão superior'].str.len()
# Out:
# 0        22
# 1        20
# 2        22
# 3        20
# 4        20
#          ..
# 88902    62
# 88903    62
# 88904    62
# 88905    62
# 88906    62
# Name: Nome do órgão superior, Length: 88907, dtype: int64

# %%
df_viagem['Nome do órgão superior'].str.upper().str.replace('MINISTÉRIO', 'MIN.')
# Out:
# 0                                         MIN. DA EDUCAÇÃO
# 1                                           MIN. DA DEFESA
# 2                                         MIN. DA EDUCAÇÃO
# 3                                           MIN. DA DEFESA
# 4                                           MIN. DA DEFESA
#                                ...
# 88902    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88903    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88904    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88905    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# 88906    BANCO CENTRAL DO BRASIL - ORÇAMENTO FISCAL E S...
# Name: Nome do órgão superior, Length: 88907, dtype: object

# %%
df_viagem[['Valor diárias', 'Valor passagens']]
# Out:
#       Valor diárias Valor passagens
# 0            107,83            0,00
# 1              0,00         5927,18
# 2              0,00            0,00
# 3              0,00         5927,18
# 4              0,00         5927,18
# ...             ...             ...
# 88902        904,09         1768,81
# 88903       2758,64         5309,51
# 88904       2758,64         5309,51
# 88905       1204,09         2327,04
# 88906       1109,09         2544,81
#
# [88907 rows x 2 columns]

# %%
df_viagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88907 entries, 0 to 88906
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Identificador do processo de viagem  88907 non-null  int64
#  1   Número da Proposta (PCDP)            88907 non-null  object
#  2   Situação                             88907 non-null  object
#  3   Viagem Urgente                       88907 non-null  object
#  4   Justificativa Urgência Viagem        88884 non-null  object
#  5   Código do órgão superior             88907 non-null  int64
#  6   Nome do órgão superior               88907 non-null  object
#  7   Código órgão solicitante             88907 non-null  int64
#  8   Nome órgão solicitante               88907 non-null  object
#  9   CPF viajante                         85277 non-null  object
#  10  Nome                                 88907 non-null  object
# ...

# %%
lista = ['Valor diárias', 'Valor passagens', 'Valor devolução', 'Valor outros gastos']

for i in lista:
    df_viagem[i] = df_viagem[i].str.replace(',', '.').astype(float)

# %%
df_viagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88907 entries, 0 to 88906
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Identificador do processo de viagem  88907 non-null  int64
#  1   Número da Proposta (PCDP)            88907 non-null  object
#  2   Situação                             88907 non-null  object
#  3   Viagem Urgente                       88907 non-null  object
#  4   Justificativa Urgência Viagem        88884 non-null  object
#  5   Código do órgão superior             88907 non-null  int64
#  6   Nome do órgão superior               88907 non-null  object
#  7   Código órgão solicitante             88907 non-null  int64
#  8   Nome órgão solicitante               88907 non-null  object
#  9   CPF viajante                         85277 non-null  object
#  10  Nome                                 88907 non-null  object
# ...

# %%
#df_viagem = pd.read_csv('2026_Viagem.csv', encoding='latin', sep=';', decimal=',') para não ter problema com a troca de , por .

# %%
df_viagem['Valor diárias'] + df_viagem['Valor passagens']
# Out:
# 0         107.83
# 1        5927.18
# 2           0.00
# 3        5927.18
# 4        5927.18
#           ...
# 88902    2672.90
# 88903    8068.15
# 88904    8068.15
# 88905    3531.13
# 88906    3653.90
# Length: 88907, dtype: float64

# %% [markdown]
# ###Agrupamentos

# %%
df_viagem['Despesas'] = df_viagem['Valor diárias'] + df_viagem['Valor passagens'] + df_viagem['Valor outros gastos']
df_viagem.head(3)
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)   Situação  \
# 0                             21116870                 000073/26  Realizada
# 1                             21342207                 000001/26  Realizada
# 2                             21343024                 000001/26  Realizada
#
#   Viagem Urgente Justificativa Urgência Viagem  Código do órgão superior  \
# 0            SIM         Atraso na solicitação                     26000
# 1            NÃO                Sem informação                     52000
# 2            NÃO                Sem informação                     26000
#
#    Nome do órgão superior  Código órgão solicitante  \
# 0  Ministério da Educação                     26436
# 1    Ministério da Defesa                     52121
# 2  Ministério da Educação                     26247
#
#                               Nome órgão solicitante    CPF viajante  \
# 0  Instituto Federal de Educação, Ciência e Tecno...  ***.240.140-**
# ...

# %%
df_viagem['Cargo'].value_counts() #mostra todos os cargos e conta quantas vezes esse cargo apareceu na coluna
# Out:
# Cargo
# Informações protegidas por sigilo          14140
# PROFESSOR DO MAGISTERIO SUPERIOR            3888
# PROFESSOR ENS BASICO TECN TECNOLOGICO       3060
# AUDITOR FISCAL FEDERAL AGROPECUARIO         2856
# ANALISTA AMBIENTAL                          2164
#                                            ...
# CIRURGIAO DENTISTA - 30H                       1
# FISC DERIV DE PETROLEO E O COMBUSTIVEIS        1
# TECNICO DE COLONIZACAO                         1
# REVISOR DE TEXTOS                              1
# TECNICO DE ARQUIVO                             1
# Name: count, Length: 540, dtype: int64

# %%
(df_viagem['Cargo'].value_counts(normalize=True) * 100).round(2).rename('Proporção de viagens').reset_index() #Mostra o resultado em porcentagem
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 24.10
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                  6.63
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  5.22
# 3        AUDITOR FISCAL FEDERAL AGROPECUARIO                  4.87
# 4                         ANALISTA AMBIENTAL                  3.69
# ..                                       ...                   ...
# 535                 CIRURGIAO DENTISTA - 30H                  0.00
# 536  FISC DERIV DE PETROLEO E O COMBUSTIVEIS                  0.00
# 537                   TECNICO DE COLONIZACAO                  0.00
# 538                        REVISOR DE TEXTOS                  0.00
# 539                       TECNICO DE ARQUIVO                  0.00
#
# [540 rows x 2 columns]

# %%
#pd.set_option('display.float', '{:.2f}')
df_viagem.groupby('Cargo')['Despesas'].sum().reset_index().sort_values(by='Despesas', ascending=False)
# Out:
#                                         Cargo     Despesas
# 297         Informações protegidas por sigilo  41843176.28
# 374          PROFESSOR DO MAGISTERIO SUPERIOR  10356392.43
# 144  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL   6277491.68
# 375     PROFESSOR ENS BASICO TECN TECNOLOGICO   5377014.77
# 453                  TECNICO DO SEGURO SOCIAL   4876261.71
# ..                                        ...          ...
# 225          DESENHISTA TECNICO ESPECIALIZADO       114.09
# 351                 PESQUISADOR EM GEOCIENCIA         0.00
# 220            DATILOGRAFO DE TEXTOS GRAFICOS         0.00
# 534                                TRATORISTA         0.00
# 160                      AUXILIAR DE ARTIFICE         0.00
#
# [540 rows x 2 columns]

# %%
df_viagem.groupby('Cargo')['Despesas'].mean().reset_index().sort_values(by='Despesas', ascending=False)
# Out:
#                                 Cargo      Despesas
# 507   TECNICO MKT E PROPAGANDA JUNIOR  25815.760000
# 364                 PRIMEIRO SARGENTO  19532.113333
# 317        MINISTRO DE SEGUNDA CLASSE  17865.784583
# 316       MINISTRO DE PRIMEIRA CLASSE  16821.712899
# 122         ASSISTENTE DE CHANCELARIA  16756.785000
# ..                                ...           ...
# 225  DESENHISTA TECNICO ESPECIALIZADO     57.045000
# 351         PESQUISADOR EM GEOCIENCIA      0.000000
# 534                        TRATORISTA      0.000000
# 160              AUXILIAR DE ARTIFICE      0.000000
# 220    DATILOGRAFO DE TEXTOS GRAFICOS      0.000000
#
# [540 rows x 2 columns]

# %%
df_viagem.groupby('Cargo')['Despesas'].max().reset_index().sort_values(by='Despesas', ascending=False)
# Out:
#                                 Cargo   Despesas
# 374  PROFESSOR DO MAGISTERIO SUPERIOR  122284.54
# 317        MINISTRO DE SEGUNDA CLASSE  117374.61
# 70   ANALISTA EM CIENCIA E TECNOLOGIA  114266.94
# 60        ANALISTA DE INFRA-ESTRUTURA  113567.60
# 316       MINISTRO DE PRIMEIRA CLASSE  110299.69
# ..                                ...        ...
# 236             EDITOR DE PUBLICACOES     114.09
# 534                        TRATORISTA       0.00
# 220    DATILOGRAFO DE TEXTOS GRAFICOS       0.00
# 351         PESQUISADOR EM GEOCIENCIA       0.00
# 160              AUXILIAR DE ARTIFICE       0.00
#
# [540 rows x 2 columns]

# %%
df_viagem.groupby('Cargo')['Despesas'].min().reset_index().sort_values(by='Despesas', ascending=False)
# Out:
#                                         Cargo  Despesas
# 507           TECNICO MKT E PROPAGANDA JUNIOR  25815.76
# 364                         PRIMEIRO SARGENTO  15242.50
# 59                    ANALISTA DE INFORMACOES  12510.46
# 135                         ASSITENTE TECNICO  11005.70
# 40       ANALISTA - ANALISTA DE CONTABILIDADE  10530.64
# ..                                        ...       ...
# 198                                   BIOLOGO      0.00
# 197              BIBLIOTECARIO-DOCUMENTALISTA      0.00
# 194                          AUXILIAR TECNICO      0.00
# 191        AUXILIAR OPERACIONAL SERV DIVERSOS      0.00
# 270  ESPECIALISTA CET PROD INOV SAUDE PUBLICA      0.00
#
# [540 rows x 2 columns]

# %% [markdown]
# ###Series booleanas e filtros

# %%
viagem_cargo = (df_viagem['Cargo'].value_counts(normalize=True) * 100).round(2).rename('Proporção de viagens').reset_index()

# %%
filtro_mais_1porcetn = viagem_cargo['Proporção de viagens'] > 1

# %%
viagem_cargo[filtro_mais_1porcetn]
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 24.10
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                  6.63
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  5.22
# 3        AUDITOR FISCAL FEDERAL AGROPECUARIO                  4.87
# 4                         ANALISTA AMBIENTAL                  3.69
# 5   AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL                  3.55
# 6                CONTRATADO LEI 8745/93 - NI                  3.10
# 7                   TECNICO DO SEGURO SOCIAL                  2.53
# 8     ANALISTA TRIBUTARIO REC FEDERAL BRASIL                  2.51
# 9           AGENTE DE PESQ E MAPEAMENTO - NI                  2.24
# 10   TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.85
# 11                AUDITOR FISCAL DO TRABALHO                  1.70
# 12               ASSISTENTE EM ADMINISTRAçãO                  1.63
# ...

# %%
filtro_tecnico = viagem_cargo['Cargo'].str.startswith('TECNICO')

# %%
viagem_cargo[filtro_tecnico]
# Out:
#                                        Cargo  Proporção de viagens
# 7                   TECNICO DO SEGURO SOCIAL                  2.53
# 10   TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.85
# 17                         TECNICO AMBIENTAL                  1.03
# 22                    TECNICO ADMINISTRATIVO                  0.76
# 33   TECNICO SUPORTE INFRA-ESTRUT TRANSPORTE                  0.46
# ..                                       ...                   ...
# 519                  TECNICO DE PLANEJAMENTO                  0.00
# 526                   TECNICO EM AGRIMENSURA                  0.00
# 530                              TECNICO III                  0.00
# 537                   TECNICO DE COLONIZACAO                  0.00
# 539                       TECNICO DE ARQUIVO                  0.00
#
# [89 rows x 2 columns]

# %%
viagem_cargo[filtro_tecnico & filtro_mais_1porcetn]
# Out:
#                                       Cargo  Proporção de viagens
# 7                  TECNICO DO SEGURO SOCIAL                  2.53
# 10  TECNICO INFOR GEOGRAFICAS E ESTATISTICA                  1.85
# 17                        TECNICO AMBIENTAL                  1.03

# %%
viagem_cargo[filtro_tecnico | filtro_mais_1porcetn]
# Out:
#                                      Cargo  Proporção de viagens
# 0        Informações protegidas por sigilo                 24.10
# 1         PROFESSOR DO MAGISTERIO SUPERIOR                  6.63
# 2    PROFESSOR ENS BASICO TECN TECNOLOGICO                  5.22
# 3      AUDITOR FISCAL FEDERAL AGROPECUARIO                  4.87
# 4                       ANALISTA AMBIENTAL                  3.69
# ..                                     ...                   ...
# 519                TECNICO DE PLANEJAMENTO                  0.00
# 526                 TECNICO EM AGRIMENSURA                  0.00
# 530                            TECNICO III                  0.00
# 537                 TECNICO DE COLONIZACAO                  0.00
# 539                     TECNICO DE ARQUIVO                  0.00
#
# [105 rows x 2 columns]

# %%
viagem_cargo
# Out:
#                                        Cargo  Proporção de viagens
# 0          Informações protegidas por sigilo                 24.10
# 1           PROFESSOR DO MAGISTERIO SUPERIOR                  6.63
# 2      PROFESSOR ENS BASICO TECN TECNOLOGICO                  5.22
# 3        AUDITOR FISCAL FEDERAL AGROPECUARIO                  4.87
# 4                         ANALISTA AMBIENTAL                  3.69
# ..                                       ...                   ...
# 535                 CIRURGIAO DENTISTA - 30H                  0.00
# 536  FISC DERIV DE PETROLEO E O COMBUSTIVEIS                  0.00
# 537                   TECNICO DE COLONIZACAO                  0.00
# 538                        REVISOR DE TEXTOS                  0.00
# 539                       TECNICO DE ARQUIVO                  0.00
#
# [540 rows x 2 columns]

# %%
carog_despesas = df_viagem.groupby('Cargo')['Despesas'].sum().reset_index().sort_values(by='Despesas')

# %%
filtro_despesas = (carog_despesas['Despesas'] > 10_000_000) # ou carog_despesas[carog_despesas['Despesas] > 10000000]
carog_despesas[filtro_despesas].sort_values(by='Despesas', ascending=False)
# Out:
#                                  Cargo     Despesas
# 297  Informações protegidas por sigilo  41843176.28
# 374   PROFESSOR DO MAGISTERIO SUPERIOR  10356392.43

# %% [markdown]
# ###Lidando com dados nulos

# %%
df_viagem['Cargo'].value_counts(dropna=False)
# Out:
# Cargo
# NaN                                        30246
# Informações protegidas por sigilo          14140
# PROFESSOR DO MAGISTERIO SUPERIOR            3888
# PROFESSOR ENS BASICO TECN TECNOLOGICO       3060
# AUDITOR FISCAL FEDERAL AGROPECUARIO         2856
#                                            ...
# CIRURGIAO DENTISTA - 30H                       1
# FISC DERIV DE PETROLEO E O COMBUSTIVEIS        1
# TECNICO DE COLONIZACAO                         1
# REVISOR DE TEXTOS                              1
# TECNICO DE ARQUIVO                             1
# Name: count, Length: 541, dtype: int64

# %%
df_viagem.dropna(subset='Cargo')
# Out:
#        Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                 21116870                 000073/26
# 2                                 21343024                 000001/26
# 14                                21399788              000001/26-1C
# 17                                21405748                 000001/26
# 19                                21417753              000001/26-1C
# ...                                    ...                       ...
# 88902                           2026000104             Sem informaçã
# 88903                           2026000113             Sem informaçã
# 88904                           2026000114             Sem informaçã
# 88905                           2026000115             Sem informaçã
# 88906                           2026000128             Sem informaçã
#
#         Situação Viagem Urgente  \
# 0      Realizada            SIM
# 2      Realizada            NÃO
# 14     Realizada            SIM
# ...

# %%
df_viagem['Cargo'].fillna('NÃO IDENTIFICADO')
# Out:
# 0                            PEDAGOGO-AREA
# 1                         NÃO IDENTIFICADO
# 2         PROFESSOR DO MAGISTERIO SUPERIOR
# 3                         NÃO IDENTIFICADO
# 4                         NÃO IDENTIFICADO
#                        ...
# 88902            ANALISTA DO BANCO CENTRAL
# 88903             TECNICO DO BANCO CENTRAL
# 88904             TECNICO DO BANCO CENTRAL
# 88905            ANALISTA DO BANCO CENTRAL
# 88906    DIRETOR SERVIDOR DO BANCO CENTRAL
# Name: Cargo, Length: 88907, dtype: object

# %%
df_viagem[['Período - Data de início', 'Período - Data de fim']]
# Out:
#       Período - Data de início Período - Data de fim
# 0                   25/02/2026            25/02/2026
# 1                   09/01/2026            10/01/2026
# 2                   28/02/2026            08/03/2026
# 3                   09/01/2026            10/01/2026
# 4                   09/01/2026            10/01/2026
# ...                        ...                   ...
# 88902               24/02/2026            25/02/2026
# 88903               08/02/2026            11/02/2026
# 88904               08/02/2026            11/02/2026
# 88905               06/02/2026            11/02/2026
# 88906               25/02/2026            26/02/2026
#
# [88907 rows x 2 columns]

# %%
df_viagem['Período - Data de início'] = pd.to_datetime(df_viagem['Período - Data de início'], format='%d/%m/%Y')
df_viagem['Período - Data de fim'] = pd.to_datetime(df_viagem['Período - Data de fim'], format='%d/%m/%Y')
#df['coluna'] = pd.to_datetime(df['coluna'], dayfirst=True) -> O parâmetro dayfirst=True diz ao pandas que o dia vem antes do mês.

# %%
df_viagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88907 entries, 0 to 88906
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Identificador do processo de viagem  88907 non-null  int64
#  1   Número da Proposta (PCDP)            88907 non-null  object
#  2   Situação                             88907 non-null  object
#  3   Viagem Urgente                       88907 non-null  object
#  4   Justificativa Urgência Viagem        88884 non-null  object
#  5   Código do órgão superior             88907 non-null  int64
#  6   Nome do órgão superior               88907 non-null  object
#  7   Código órgão solicitante             88907 non-null  int64
#  8   Nome órgão solicitante               88907 non-null  object
#  9   CPF viajante                         85277 non-null  object
#  10  Nome                                 88907 non-null  object
# ...

# %%
df_viagem['Período - Data de início'].dt.month_name()
# Out:
# 0        February
# 1         January
# 2        February
# 3         January
# 4         January
#            ...
# 88902    February
# 88903    February
# 88904    February
# 88905    February
# 88906    February
# Name: Período - Data de início, Length: 88907, dtype: object

# %%
df_viagem['Dias de viagem'] = (df_viagem['Período - Data de fim'] - df_viagem['Período - Data de início']).dt.days
df_viagem.head(3)
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)   Situação  \
# 0                             21116870                 000073/26  Realizada
# 1                             21342207                 000001/26  Realizada
# 2                             21343024                 000001/26  Realizada
#
#   Viagem Urgente Justificativa Urgência Viagem  Código do órgão superior  \
# 0            SIM         Atraso na solicitação                     26000
# 1            NÃO                Sem informação                     52000
# 2            NÃO                Sem informação                     26000
#
#    Nome do órgão superior  Código órgão solicitante  \
# 0  Ministério da Educação                     26436
# 1    Ministério da Defesa                     52121
# 2  Ministério da Educação                     26247
#
#                               Nome órgão solicitante    CPF viajante  \
# 0  Instituto Federal de Educação, Ciência e Tecno...  ***.240.140-**
# ...

# %%
(df_viagem['Período - Data de fim'] - df_viagem['Período - Data de início']).dt.days.value_counts()
# Out:
# 1     16303
# 2     15101
# 0     14329
# 4     11380
# 3     11133
#       ...
# 66        2
# 73        2
# 70        2
# 79        1
# 89        1
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# ###Combiando agregações e filtros

# %%
(
    df_viagem
    .groupby('Cargo')
    .agg(
        despesa_media = ('Despesas', 'mean'), 
        duracao_media = ('Dias de viagem', 'mean'),
        despesas_totais = ('Despesas', 'sum'),
        destinos_mais_frequentes = ('Destinos', pd.Series.mode),
        n_viagens = ('Nome', 'count'),
        )
    .reset_index()
    )
# Out:
#                            Cargo  despesa_media  duracao_media  \
# 0    AAD-AUXILIAR ADMINISTRATIVO     571.216667       1.333333
# 1      AAD-AUXILIAR DE OPERACOES    2210.000000       6.000000
# 2                  ADMINISTRADOR    1942.100363       2.095710
# 3      ADMINISTRADOR DE EMPRESAS    6460.380000       3.000000
# 4                ADMINISTRADOR I    4896.110000       2.500000
# ..                           ...            ...            ...
# 535              TRATORISTA - NA    3036.810000      10.000000
# 536                VAQUEIRO - NA    2049.655000       8.500000
# 537                    VIGILANTE     488.261064       0.914894
# 538          VISITADOR SANITARIO    1501.277000       3.000000
# 539                  ZOOTECNISTA     587.913333       1.000000
#
#      despesas_totais                           destinos_mais_frequentes  \
# 0            1713.65                                        Alcantil/PB
# ...

# %%
df_cargos = df_viagem['Cargo'].value_counts(normalize=True).reset_index()

# %%
df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']
# Out:
# 0            Informações protegidas por sigilo
# 1             PROFESSOR DO MAGISTERIO SUPERIOR
# 2        PROFESSOR ENS BASICO TECN TECNOLOGICO
# 3          AUDITOR FISCAL FEDERAL AGROPECUARIO
# 4                           ANALISTA AMBIENTAL
# 5     AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL
# 6                  CONTRATADO LEI 8745/93 - NI
# 7                     TECNICO DO SEGURO SOCIAL
# 8       ANALISTA TRIBUTARIO REC FEDERAL BRASIL
# 9             AGENTE DE PESQ E MAPEAMENTO - NI
# 10     TECNICO INFOR GEOGRAFICAS E ESTATISTICA
# 11                  AUDITOR FISCAL DO TRABALHO
# 12                 ASSISTENTE EM ADMINISTRAçãO
# 13    AGENTE DE INSP SANIT IND PROD ORIGEM ANI
# 14                             ENGENHEIRO-AREA
# 15                       AGENTE ADMINISTRATIVO
# 16                                   MOTORISTA
# 17                           TECNICO AMBIENTAL
# 18      ANALISTA INFRA-ESTRUTURA DE TRANSPORTE
# Name: Cargo, dtype: object

# %%
df_viagem_consolidado = (
    df_viagem
    .groupby('Cargo')
    .agg(
        despesa_media = ('Despesas', 'mean'), 
        duracao_media = ('Dias de viagem', 'mean'),
        despesas_totais = ('Despesas', 'sum'),
        destinos_mais_frequentes = ('Destinos', pd.Series.mode),
        n_viagens = ('Nome', 'count'),
        )
    .reset_index()
    )

# %%
cargos_relevantes = df_cargos.loc[df_cargos['proportion'] > 0.01, 'Cargo']

# %%
filtro = df_viagem_consolidado['Cargo'].isin(cargos_relevantes)

# %%
df_final = df_viagem_consolidado[filtro]
df_final
# Out:
#                                         Cargo  despesa_media  duracao_media  \
# 9                       AGENTE ADMINISTRATIVO    2807.262567       3.671123
# 16   AGENTE DE INSP SANIT IND PROD ORIGEM ANI     569.744956       1.404814
# 19           AGENTE DE PESQ E MAPEAMENTO - NI     730.476816       2.051790
# 55                         ANALISTA AMBIENTAL    1855.402546       4.340573
# 76     ANALISTA INFRA-ESTRUTURA DE TRANSPORTE    3015.724833       2.214047
# 83     ANALISTA TRIBUTARIO REC FEDERAL BRASIL    2035.797510       3.026531
# 126               ASSISTENTE EM ADMINISTRAçãO    1062.562252       1.551616
# 142                AUDITOR FISCAL DO TRABALHO    1157.410120       2.226680
# 143       AUDITOR FISCAL FEDERAL AGROPECUARIO    1198.591611       1.679272
# 144  AUDITOR-FISCAL DA RECEITA FEDERAL BRASIL    3012.232092       2.932342
# 214               CONTRATADO LEI 8745/93 - NI     705.515171       1.972467
# ...

# %% [markdown]
# ###Criando e customizando um gráfico

# %%
df_final = df_final.sort_values(by='n_viagens', ascending=False)

# %%
df_final.plot(x ='Cargo', y='n_viagens', kind='bar')
# Out:
# <Axes: xlabel='Cargo'>

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots(figsize=(16,6))
ax.barh(df_final['Cargo'], df_final['n_viagens'], color='#49deac')
ax.invert_yaxis()
ax.set_facecolor('#3b3b47')
fig.suptitle('Viagens por cargo público (2026)')
plt.figtext(0.65, 0.89, 'Fonte: Portal da Transparência', fontsize=8)
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.yticks(fontsize=8)
plt.xlabel('Número de viagens')
plt.savefig('figura_tabela.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ###Análise exploratória de dados

# %%
df_viagem.head(3)
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)   Situação  \
# 0                             21116870                 000073/26  Realizada
# 1                             21342207                 000001/26  Realizada
# 2                             21343024                 000001/26  Realizada
#
#   Viagem Urgente Justificativa Urgência Viagem  Código do órgão superior  \
# 0            SIM         Atraso na solicitação                     26000
# 1            NÃO                Sem informação                     52000
# 2            NÃO                Sem informação                     26000
#
#    Nome do órgão superior  Código órgão solicitante  \
# 0  Ministério da Educação                     26436
# 1    Ministério da Defesa                     52121
# 2  Ministério da Educação                     26247
#
#                               Nome órgão solicitante    CPF viajante  \
# 0  Instituto Federal de Educação, Ciência e Tecno...  ***.240.140-**
# ...

# %%
fig, ax = plt.subplots(figsize=(16,6))
ax.scatter(df_viagem['Dias de viagem'], df_viagem['Despesas'], alpha=0.2)
#ax.set_xlim(0, 100)
#ax.set_ylim(0, 25_000)

# %%
(df_viagem['Despesas'] > 120_000).value_counts()
# Out:
# Despesas
# False    88904
# True         3
# Name: count, dtype: int64

# %%
df_viagem[df_viagem['Despesas'] > 120_000]
# Out:
#        Identificador do processo de viagem Número da Proposta (PCDP)  \
# 3452                              21710906                 000052/26
# 20123                             21742750              001308/26-3C
# 51203                             21789674                 001180/26
#
#             Situação Viagem Urgente  \
# 3452       Realizada            SIM
# 20123  Não realizada            SIM
# 51203      Realizada            SIM
#
#                            Justificativa Urgência Viagem  \
# 3452   Não foi possível atender à exigência de prazo ...
# 20123  Esta Nota de Serviço não foi emitida com prazo...
# 51203  Justifica-se tendo em vista a intempestividade...
#
#        Código do órgão superior  \
# 3452                      46000
# 20123                     52000
# 51203                     36000
#
#                                   Nome do órgão superior  \
# 3452   Ministério da Gestão e da Inovação em Serviços...
# ...

# %%
df_passagens = pd.read_csv('2026_Passagem.csv', encoding='latin', sep=';')
df_passagens.head(3)
# Out:
#    Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                             21342207                 000001/26
# 1                             21346664                 000002/26
# 2                             21347000                 000003/26
#
#   Meio de transporte País - Origem ida UF - Origem ida Cidade - Origem ida  \
# 0              Aéreo            Brasil           Ceará           Fortaleza
# 1              Aéreo            Brasil           Ceará           Fortaleza
# 2              Aéreo            Brasil           Ceará           Fortaleza
#
#           País - Destino ida UF - Destino ida Cidade - Destino ida  \
# 0  Estados Unidos da América              NaN           Washington
# 1  Estados Unidos da América              NaN           Washington
# 2  Estados Unidos da América              NaN           Washington
#
#   País - Origem volta UF - Origem volta Cidade - Origem volta  \
# 0      Sem informação    Sem informação        Sem informação
# ...

# %%
df_passagens[df_passagens['Identificador do processo de viagem'] == 21742750]
# Out:
#        Identificador do processo de viagem Número da Proposta (PCDP)  \
# 16223                             21742750              001308/26-3C
# 16224                             21742750              001308/26-3C
# 16225                             21742750              001308/26-3C
# 16226                             21742750              001308/26-3C
#
#       Meio de transporte          País - Origem ida   UF - Origem ida  \
# 16223              Aéreo  Estados Unidos da América               NaN
# 16224              Aéreo  Estados Unidos da América               NaN
# 16225              Aéreo                     Brasil  Distrito Federal
# 16226              Aéreo                     Brasil  Distrito Federal
#
#       Cidade - Origem ida         País - Destino ida  UF - Destino ida  \
# 16223          Washington                   Alemanha               NaN
# 16224          Washington                     Brasil  Distrito Federal
# ...

# %%
df_viagem.merge(df_passagens)
# Out:
#        Identificador do processo de viagem Número da Proposta (PCDP)  \
# 0                                 21342207                 000001/26
# 1                                 21346664                 000002/26
# 2                                 21347000                 000003/26
# 3                                 21347334                 000004/26
# 4                                 21354924                 000005/26
# ...                                    ...                       ...
# 48963                           2026000114             Sem informaçã
# 48964                           2026000114             Sem informaçã
# 48965                           2026000115             Sem informaçã
# 48966                           2026000128             Sem informaçã
# 48967                           2026000128             Sem informaçã
#
#         Situação Viagem Urgente Justificativa Urgência Viagem  \
# 0      Realizada            NÃO                Sem informação
# ...

# %%
df_final.to_csv('tabela_final.csv', index=False)
