# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %% [markdown]
# ###iloc e filtros

# %%
df = pd.DataFrame(randn(5,4), index = ['A', 'B', 'C', 'D', 'E'], columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A -0.612610 -0.891929  0.737243 -0.048359
# B -1.490728 -0.457706  1.175521  1.122740
# C  0.659543 -0.139012 -0.329176 -3.359584
# D -1.867315  0.909677 -0.346163 -0.437328
# E  1.965925  0.324521 -0.514014  0.782265

# %%
df.loc[['A', 'B'], ['W']] #df.loc[[linas], [colunas]]
# Out:
#           W
# A -0.831372
# B  0.630400

# %%
df.iloc[:-1, 1:]
# Out:
#           X         Y         Z
# A  0.780175 -1.558022  1.747009
# B  0.520423  0.270541 -0.853713
# C  0.326395 -1.960027  0.463300
# D -0.787614 -1.763595 -0.266915

# %%
df.iloc[:-1, 1:4] #[incluso:excluso]
# Out:
#           X         Y         Z
# A  0.780175 -1.558022  1.747009
# B  0.520423  0.270541 -0.853713
# C  0.326395 -1.960027  0.463300
# D -0.787614 -1.763595 -0.266915

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False   True  False   True
# B   True   True   True  False
# C   True   True  False   True
# D  False  False  False  False
# E   True  False  False   True

# %%
df[df> 0]
# Out:
#           W         X         Y         Z
# A       NaN  0.780175       NaN  1.747009
# B  0.630400  0.520423  0.270541       NaN
# C  0.720209  0.326395       NaN  0.463300
# D       NaN       NaN       NaN       NaN
# E  0.249056       NaN       NaN  0.324708

# %%
df['Y'] > 0
# Out:
# A    False
# B     True
# C    False
# D    False
# E    False
# Name: Y, dtype: bool

# %%
df[df['Y'] > 0]
# Out:
#         W         X         Y         Z
# B  0.6304  0.520423  0.270541 -0.853713

# %%
df[(df['Y'] > 0) & (df['X'] > 0)]
# Out:
#         W         X         Y         Z
# B  0.6304  0.520423  0.270541 -0.853713

# %% [markdown]
# ###Operações com índices

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.reset_index() #mostra uma cópia. Para ser real teria que colocar o inplace=True
# Out:
#   index         W         X         Y         Z
# 0     A -0.612610 -0.891929  0.737243 -0.048359
# 1     B -1.490728 -0.457706  1.175521  1.122740
# 2     C  0.659543 -0.139012 -0.329176 -3.359584
# 3     D -1.867315  0.909677 -0.346163 -0.437328
# 4     E  1.965925  0.324521 -0.514014  0.782265

# %%
#Para voltar ao que era é só escrever df.set_index('index', inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.612610 -0.891929  0.737243 -0.048359
# B -1.490728 -0.457706  1.175521  1.122740
# C  0.659543 -0.139012 -0.329176 -3.359584
# D -1.867315  0.909677 -0.346163 -0.437328
# E  1.965925  0.324521 -0.514014  0.782265

# %%
novo_ind = 'CA NY WY OR CO'.split()
novo_ind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['novo_index'] = novo_ind
#df.set_index('novo_index') com esse comando o Pandas retira a coluna de index antiga e coloca a nova
df.reset_index().set_index('novo_index')
# Out:
#            index         W         X         Y         Z
# novo_index
# CA             A -0.612610 -0.891929  0.737243 -0.048359
# NY             B -1.490728 -0.457706  1.175521  1.122740
# WY             C  0.659543 -0.139012 -0.329176 -3.359584
# OR             D -1.867315  0.909677 -0.346163 -0.437328
# CO             E  1.965925  0.324521 -0.514014  0.782265
