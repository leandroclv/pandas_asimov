# %%
import pandas as pd
import numpy as np
from numpy.random import randn

# %% [markdown]
# ###iloc e filtros

# %%
df = pd.DataFrame(randn(5,4), index = ['A', 'B', 'C', 'D', 'E'], columns='W X Y Z'.split())
df
# Out:
#           W         X         Y         Z
# A -0.314913  0.602280 -1.010903  0.462778
# B  1.699415  0.139542  1.000556  0.957494
# C  0.378432 -0.386527  0.248565  0.535332
# D  0.329257 -1.751821  0.948934 -1.403029
# E -1.072943 -0.867668  2.626043 -1.756235

# %%
df.loc[['A', 'B'], ['W']] #df.loc[[linas], [colunas]]
# Out:
#           W
# A -0.314913
# B  1.699415

# %%
df.iloc[:-1, 1:]
# Out:
#           X         Y         Z
# A  0.602280 -1.010903  0.462778
# B  0.139542  1.000556  0.957494
# C -0.386527  0.248565  0.535332
# D -1.751821  0.948934 -1.403029

# %%
df.iloc[:-1, 1:4] #[incluso:excluso]
# Out:
#           X         Y         Z
# A  0.602280 -1.010903  0.462778
# B  0.139542  1.000556  0.957494
# C -0.386527  0.248565  0.535332
# D -1.751821  0.948934 -1.403029

# %%
df > 0
# Out:
#        W      X      Y      Z
# A  False   True  False   True
# B   True   True   True   True
# C   True  False   True   True
# D   True  False   True  False
# E  False  False   True  False

# %%
df[df> 0]
# Out:
#           W         X         Y         Z
# A       NaN  0.602280       NaN  0.462778
# B  1.699415  0.139542  1.000556  0.957494
# C  0.378432       NaN  0.248565  0.535332
# D  0.329257       NaN  0.948934       NaN
# E       NaN       NaN  2.626043       NaN

# %%
df['Y'] > 0
# Out:
# A    False
# B     True
# C     True
# D     True
# E     True
# Name: Y, dtype: bool

# %%
df[df['Y'] > 0]
# Out:
#           W         X         Y         Z
# B  1.699415  0.139542  1.000556  0.957494
# C  0.378432 -0.386527  0.248565  0.535332
# D  0.329257 -1.751821  0.948934 -1.403029
# E -1.072943 -0.867668  2.626043 -1.756235

# %%
df[(df['Y'] > 0) & (df['X'] > 0)]
# Out:
#           W         X         Y         Z
# B  1.699415  0.139542  1.000556  0.957494

# %% [markdown]
# ###Operações com índices

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.reset_index() #mostra uma cópia. Para ser real teria que colocar o inplace=True
# Out:
#   index         W         X         Y         Z
# 0     A -0.314913  0.602280 -1.010903  0.462778
# 1     B  1.699415  0.139542  1.000556  0.957494
# 2     C  0.378432 -0.386527  0.248565  0.535332
# 3     D  0.329257 -1.751821  0.948934 -1.403029
# 4     E -1.072943 -0.867668  2.626043 -1.756235

# %%
#Para voltar ao que era é só escrever df.set_index('index', inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.314913  0.602280 -1.010903  0.462778
# B  1.699415  0.139542  1.000556  0.957494
# C  0.378432 -0.386527  0.248565  0.535332
# D  0.329257 -1.751821  0.948934 -1.403029
# E -1.072943 -0.867668  2.626043 -1.756235

# %%
novo_ind = 'CA NY WY OR CO'.split()
novo_ind
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['novo_index'] = novo_ind
#df.set_index('novo_index') com esse comando o Pandas retira a coluna de index antiga e coloca a nova
df.reset_index().set_index('novo_index')
# Out:
#            index         W         X         Y         Z
# novo_index
# CA             A -0.314913  0.602280 -1.010903  0.462778
# NY             B  1.699415  0.139542  1.000556  0.957494
# WY             C  0.378432 -0.386527  0.248565  0.535332
# OR             D  0.329257 -1.751821  0.948934 -1.403029
# CO             E -1.072943 -0.867668  2.626043 -1.756235

# %% [markdown]
# ###Hierarquia de índices e índices múltiplos

# %%
outside = ['G1', 'G1', 'G1', 'G2', 'G2', 'G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside, inside))
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2), index=hier_index, columns=['A', 'B'])
df
# Out:
#              A         B
# G1 1 -0.700149 -0.792172
#    2 -0.378115 -1.208144
#    3 -0.330903  0.150063
# G2 1 -1.129800 -1.726814
#    2  1.812672  0.771857
#    3 -0.188332  1.228213

# %%
df.loc['G1']
# Out:
#           A         B
# 1 -0.700149 -0.792172
# 2 -0.378115 -1.208144
# 3 -0.330903  0.150063

# %%
df.loc['G1'].loc[1]
# Out:
# A   -0.700149
# B   -0.792172
# Name: 1, dtype: float64

# %%
df.index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Grupo', 'Número']
df
# Out:
#                      A         B
# Grupo Número
# G1    1      -0.700149 -0.792172
#       2      -0.378115 -1.208144
#       3      -0.330903  0.150063
# G2    1      -1.129800 -1.726814
#       2       1.812672  0.771857
#       3      -0.188332  1.228213

# %%
df.xs('G1')
# Out:
#                A         B
# Número
# 1      -0.700149 -0.792172
# 2      -0.378115 -1.208144
# 3      -0.330903  0.150063

# %%
df.xs(1, level='Número')
# Out:
#               A         B
# Grupo
# G1    -0.700149 -0.792172
# G2    -1.129800 -1.726814

# %% [markdown]
# ###Manipulação de dados ausentes

# %%
df = pd.DataFrame({
    'A': [1,2,np.nan],
    'B': [5, np.nan, np.nan],
    'C': [1,2,3]
})
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis = 0)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna(axis = 1, thresh=2)
# Out:
#      A  C
# 0  1.0  1
# 1  2.0  2
# 2  NaN  3

# %%
df.fillna(0)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  0.0  2
# 2  0.0  0.0  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df.ffill()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  2.0  5.0  3

# %%
df.bfill()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# ###Groupby

# %%
data = {
    'Classe': ['Júnior', 'Júnior', 'Pleno', 'Pleno', 'Sênior', 'Sênior'],
    'Nome': ['Jorge', 'Carlos', 'Roberta', 'Patrícia', 'Bruno', 'Vera'],
    'Venda': [200, 120, 340, 124, 243, 350]
}

df = pd.DataFrame(data)
df
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %%
group = df.groupby('Classe')
group.sum()
# Out:
#                    Nome  Venda
# Classe
# Júnior      JorgeCarlos    320
# Pleno   RobertaPatrícia    464
# Sênior        BrunoVera    593

# %%
df.groupby('Classe').min()
# Out:
#             Nome  Venda
# Classe
# Júnior    Carlos    120
# Pleno   Patrícia    124
# Sênior     Bruno    243

# %%
df.groupby('Classe').max()
# Out:
#            Nome  Venda
# Classe
# Júnior    Jorge    200
# Pleno   Roberta    340
# Sênior     Vera    350

# %%
df2 = df.copy()

# %%
df2
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %%
df2['Venda'] = [150, 432, 190, 230, 410, 155]

# %%
df
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350

# %%
df2
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    150
# 1  Júnior    Carlos    432
# 2   Pleno   Roberta    190
# 3   Pleno  Patrícia    230
# 4  Sênior     Bruno    410
# 5  Sênior      Vera    155

# %%
df3 = pd.concat([df, df2])
df3
# Out:
#    Classe      Nome  Venda
# 0  Júnior     Jorge    200
# 1  Júnior    Carlos    120
# 2   Pleno   Roberta    340
# 3   Pleno  Patrícia    124
# 4  Sênior     Bruno    243
# 5  Sênior      Vera    350
# 0  Júnior     Jorge    150
# 1  Júnior    Carlos    432
# 2   Pleno   Roberta    190
# 3   Pleno  Patrícia    230
# 4  Sênior     Bruno    410
# 5  Sênior      Vera    155

# %%
df3.groupby(['Classe', 'Nome']).sum()
# Out:
#                  Venda
# Classe Nome
# Júnior Carlos      552
#        Jorge       350
# Pleno  Patrícia    354
#        Roberta     530
# Sênior Bruno       653
#        Vera        505
